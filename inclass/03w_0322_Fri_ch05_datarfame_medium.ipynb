# %% [markdown]
# <a href="https://colab.research.google.com/github/JUNGSEAHYUN04/2024-1-my-BDA/blob/main/inclass/03w_0322_Fri_ch05_datarfame_medium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**빅데이터 분석 프로그래밍**
# - b반 3주

# %% [markdown]
# ## 0322 빅데이터분석프로그래밍 보강

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.10/dist-packages']

# %%
import sys
import pandas as pd
import numpy as np

print(sys.version)
print(pd.__version__)
print(np.__version__)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# 1.5.3
# 1.25.2

# %%
# %config InlineBackend.figure_format ='retina' #그림 선명하게

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot([10,3,-3,1])

plt.title('그래프 제목')

plt.xlabel('직선')
plt.show()

# %% [markdown]
# #데이터분석 기초 데이터 파악하기, 다루게 쉽게 수정하기

# %% [markdown]
# | 함수 | 기능 |
# |------|------|
# |head()|앞부분 출력|
# |tail()|뒷부분 출력|
# |shape|행, 열 개수 출력|
# |info()|변수 속성 출력|
# |describe()|요약 통계량 출력|

# %%
| 함수 | 기능 |
|------|------|
|head()|앞부분 출력| #원화 표시 위에있는 작대기로 구분해서 표를 만듬/ head(),tall() 기본값이 5임, 5번째줄까지
|tail()|뒷부분 출력|
|shape|행, 열 개수 출력|#속성(프로퍼티)
|info()|변수 속성 출력|
|describe()|요약 통계량 출력|

# %%
import pandas as pd
exam = pd.read_csv("exam.csv")#교수님 깃허브 2024-BDA 저장소 git clone 저장소 주소 해서 가져오기

# %%
exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 928.0 bytes

# %%
exam.shape
# Out:
# (20, 5)

# %%
exam.describe(include="all")# include 속성 안써두 됨 다 숫자 데이터여서
#기술통계량
# Out:
#              id     nclass       math    english    science
# count  20.00000  20.000000  20.000000  20.000000  20.000000
# mean   10.50000   3.000000  57.450000  84.900000  59.450000
# std     5.91608   1.450953  20.299015  12.875517  25.292968
# min     1.00000   1.000000  20.000000  56.000000  12.000000
# 25%     5.75000   2.000000  45.750000  78.000000  45.000000
# 50%    10.50000   3.000000  54.000000  86.500000  62.500000
# 75%    15.25000   4.000000  75.750000  98.000000  78.000000
# max    20.00000   5.000000  90.000000  98.000000  98.000000

# %% [markdown]
# #mpg 데이터 파악하기

# %%
import pandas as pd
mpg = pd.read_csv("mpg.csv")

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.describe(include="all") # 이 결과가 뭐냐하고 하면 데이터 프레임이라고함
#요약해서 볼 수 있다.
# Out:
#        manufacturer        model       displ         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv         cty         hwy   fl category
# count        234  234  234.000000  234.000000  234      234
# ...

# %%
mpg.describe(include="all")[["manufacturer","model"]]
# Out:
#        manufacturer        model
# count           234          234
# unique           15           38
# top           dodge  caravan 2wd
# freq             37           11
# mean            NaN          NaN
# std             NaN          NaN
# min             NaN          NaN
# 25%             NaN          NaN
# 50%             NaN          NaN
# 75%             NaN          NaN
# max             NaN          NaN

# %%
mpg["category"] #데이터 프레임이 아님 대괄호 2개 중첩해야 데이터 프로그래밍
# Out:
# 0      compact
# 1      compact
# 2      compact
# 3      compact
# 4      compact
#         ...
# 229    midsize
# 230    midsize
# 231    midsize
# 232    midsize
# 233    midsize
# Name: category, Length: 234, dtype: object

# %%
mpg[["category"]]
# Out:
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 1 columns]

# %%
mpg[["category"]].describe()
# Out:
#        category
# count       234
# unique        7
# top         suv
# freq         62

# %%
mpg.describe(include="all")[["manufacturer","model"]].describe()
# Out:
#         manufacturer  model
# count              4      4
# unique             4      4
# top              234    234
# freq               1      1

# %%
mpg.shape
# Out:
# (234, 11)

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg.tail()
#요약 통계량 mpg: 1갤런 당 갈수 있는 마일 1열:? 2열 모델명, 3열 배기량, 4열 생산년도, 5열 실린더, 6열:?, 7열은 구동방식 8열 도심연비값(cty) 9열 고속도로 연비값 10열 연료종류 11열 자동차종류
#교재 107페이지 참고
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize

# %% [markdown]
# #**범주형 데이터**
# - 명목형: 순서가 없는 거
# - 순서형: 순서가 있는 거

# %%
mpg.fl.unique() #고유값 찾기
# Out:
# array(['p', 'r', 'e', 'd', 'c'], dtype=object)

# %%
mpg["fl"].unique() #fl은 mpg.csv 파일에 있는  0행에 속해 있다
# Out:
# array(['p', 'r', 'e', 'd', 'c'], dtype=object)

# %%
mpg["fl"].value_counts()
# Out:
# r    168
# p     52
# e      8
# d      5
# c      1
# Name: fl, dtype: int64

# %%
mpg.trans.unique()
# Out:
# array(['auto(l5)', 'manual(m5)', 'manual(m6)', 'auto(av)', 'auto(s6)',
#        'auto(l4)', 'auto(l3)', 'auto(l6)', 'auto(s5)', 'auto(s4)'],
#       dtype=object)

# %%
mpg.trans.value_counts() #값이 많은 거부터 정렬
# Out:
# auto(l4)      83
# manual(m5)    58
# auto(l5)      39
# manual(m6)    19
# auto(s6)      16
# auto(l6)       6
# auto(av)       5
# auto(s5)       3
# auto(s4)       3
# auto(l3)       2
# Name: trans, dtype: int64

# %%
mpg.trans.value_counts().sort_index()#인덱스 정렬
# Out:
# auto(av)       5
# auto(l3)       2
# auto(l4)      83
# auto(l5)      39
# auto(l6)       6
# auto(s4)       3
# auto(s5)       3
# auto(s6)      16
# manual(m5)    58
# manual(m6)    19
# Name: trans, dtype: int64

# %% [markdown]
# #함수와 메소드 차이 알아보기

# %% [markdown]
# - 내장함수 = 함수

# %%
sum([4,7,8])
# Out:
# 19

# %%
max([4,7,8])
# Out:
# 8

# %%
min([4,7,8])
# Out:
# 4

# %% [markdown]
# - 메소드

# %%
df = pd.DataFrame({'x': [1,2,3]})
df.head() #객체를 통해서 호출시 메소드
# Out:
#    x
# 0  1
# 1  2
# 2  3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       3 non-null      int64
# dtypes: int64(1)
# memory usage: 152.0 bytes

# %%
df.shape # 속성 , 메소드와 속성 구별은 소괄호 유무차이로 확인
# Out:
# (3, 1)

# %% [markdown]
# - 패키지 함수(모듈, 패키지 안)

# %%
import pandas as pd
pd.read_csv('')#접근하는게 패키지 모듈이다.

# %% [markdown]
# #113p 변수명 바꾸기 (시험예상)

# %%
df_raw=pd.DataFrame({'var1': [1,2,1],'var2': [2,3,2],'var3': [10,20,30]})
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new = df_raw

# %%
df_new
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new.rename(columns = {'var2' : 'v2'}) #열의 이름을 바꾸겠다.
# Out:
#    var1  v2  var3
# 0     1   2    10
# 1     2   3    20
# 2     1   2    30

# %%
df_new # 바뀌지 않음
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new = df_new.rename(columns = {'var2' : 'v2'})

# %%
df_new
# Out:
#    var1  v2  var3
# 0     1   2    10
# 1     2   3    20
# 2     1   2    30

# %%
df_raw #바뀌지 않음
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new = df_new.rename(index={0:"x", 1:"y", 2:'z'})# 행의 이름: index
df_new
# Out:
#    var1  v2  var3
# x     1   2    10
# y     2   3    20
# z     1   2    30

# %% [markdown]
# #pandas 홈페이지 접속 : https://pandas.pydata.org/

# %%
df_raw.rename? #도움말 생성 근데 가독성이 떨어짐--> 판다스 홈페이지 상단의 documentation 에서 검색하기

# %% [markdown]
# #파생변수 만들기 : 시험예상

# %%
df = pd.DataFrame({'v1': [4,3,6], 'v2': [2,6,1]} )
df
# Out:
#    v1  v2
# 0   4   2
# 1   3   6
# 2   6   1

# %%
#df1 = df df1=df버전으로 파생변수 만들기 뒤에 코드부터 run 해보기
df1=df.copy()
df1
# Out:
#    v1  v2
# 0   4   2
# 1   3   6
# 2   6   1

# %%
df1['var_sum']=df1["v1"]+df1["v2"]
df1
# Out:
#    v1  v2  var_sum
# 0   4   2        6
# 1   3   6        9
# 2   6   1        7

# %%
df #df1을 변경했는데 df도 변경이 됨 -->copy()로 복사
# Out:
#    v1  v2
# 0   4   2
# 1   3   6
# 2   6   1

# %%
#열: var_mean(v1,v2의 평균)
df1['var_mean']=(df1["v1"]+df1["v2"])/2
df1
# Out:
#    v1  v2  var_sum  var_mean
# 0   4   2        6       3.0
# 1   3   6        9       4.5
# 2   6   1        7       3.5

# %%
df1['var_mean']=df1[["v1", "v2"]].mean(axis=1) #df1에서  v1,v2값만 뽑아서 평균을 냄
df1
# Out:
#    v1  v2  var_sum  var_mean
# 0   4   2        6       3.0
# 1   3   6        9       4.5
# 2   6   1        7       3.5

# %%
df2 = df.copy()
df
# Out:
#    v1  v2
# 0   4   2
# 1   3   6
# 2   6   1

# %%
df2.sum(axis=1)
# Out:
# 0    6
# 1    9
# 2    7
# dtype: int64

# %%
df2["mySum"] = df2.sum(axis=1)# 이게 중요
df2
# Out:
#    v1  v2  mySum
# 0   4   2      6
# 1   3   6      9
# 2   6   1      7

# %% [markdown]
# ##mpg 통합 연비변수 (시험예상)

# %%
mpg = pd.read_csv('mpg.csv')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
#total: 통합연비변수 만들기 total = cty+hwy

# %%
mpg1= mpg.copy()
mpg1
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg1["total"] = mpg1[["cty","hwy"]].mean(axis = 1)
mpg1.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total
# 0   23.5
# 1   25.0
# 2   25.5
# 3   25.5
# 4   21.0

# %%
sum(mpg1['total'])/len(mpg1)
# Out:
# 20.14957264957265

# %%
mpg1["total"].mean()
# Out:
# 20.14957264957265

# %% [markdown]
# #조건문을 활용해 파생변수 만들기 p118

# %%
mpg1['total'].describe() # 기술(요약,기초) 통계량
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
mpg1['total'].plot.hist() #히스토그램 도수분포표 만들기
# Out:
# <Axes: ylabel='Frequency'>

# %%
mpg1['total'].plot(kind = "hist", title ="히스토그램")  #한글처리가 이상함 한글처리 코드는 수정예정임
# Out:
# <Axes: title={'center': '히스토그램'}, ylabel='Frequency'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 55176 (\N{HANGUL SYLLABLE HI}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 53664 (\N{HANGUL SYLLABLE TO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 47016 (\N{HANGUL SYLLABLE RAEM}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
import seaborn as sns
sns.histplot(mpg1,x="total")
# Out:
# <Axes: xlabel='total', ylabel='Count'>

# %% [markdown]
# ### 합격 판정 변수 만들기 p120

# %%
import numpy as np

# 20 이상이면  pass 그렇지 않으면 fail
mpg1['test'] = np.where(mpg1['total']>=20,'pass','fail')
mpg1.tail(10)
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 224   volkswagen  new beetle    2.0  1999    4    auto(l4)   f   19   26  r
# 225   volkswagen  new beetle    2.5  2008    5  manual(m5)   f   20   28  r
# 226   volkswagen  new beetle    2.5  2008    5    auto(s6)   f   20   29  r
# 227   volkswagen      passat    1.8  1999    4  manual(m5)   f   21   29  p
# 228   volkswagen      passat    1.8  1999    4    auto(l5)   f   18   29  p
# 229   volkswagen      passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen      passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen      passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen      passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen      passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        category  total  test
# 224  subcompact   22.5  pass
# 225  subcompact   24.0  pass
# 226  subcompact   24.5  pass
# ...

# %%
mpg1['test'].unique()
# Out:
# array(['pass', 'fail'], dtype=object)

# %%
count_test = mpg1['test'].value_counts() #시리즈 타입

# %%
type(count_test)
# Out:
# pandas.core.series.Series

# %%
count_test.plot.bar(rot=0) #잘 안쓰는 방법임, seaborn을 더 많이 씀
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.countplot(mpg1, x="test")
# Out:
# <Axes: xlabel='test', ylabel='count'>

# %%
sns.countplot(mpg1, x="test",hue = "test", stat="percent")
#시험예상 stat을 퍼센트로 지정하면 비율로 표시됨
#hue는 색상으로 나눠준다고 생각
# Out:
# <Axes: xlabel='test', ylabel='percent'>

# %%
sns.countplot(mpg1, x="test",hue = "model", stat="percent")
# Out:
# <Axes: xlabel='test', ylabel='percent'>

# %%
sns.countplot(mpg1, x="test",hue = "category", stat="percent")
# Out:
# <Axes: xlabel='test', ylabel='percent'>

# %%
sns.countplot(mpg1, x="test",hue = "year", stat="percent")
# Out:
# <Axes: xlabel='test', ylabel='percent'>

# %% [markdown]
# #seaborn 홈페이지: [seaborn](https://seaborn.pydata.org/)에서 검색
# data = "mpg"를 mpg로 축약해서 써두 됨
# 홈페이지에서 countPlot검색해서 들어가면 첫번째 문구에서
# seaborn.countplot(data=None, *...)라 뜨는데 이때 * 앞에서 있는 속성들은 속성값만 써도 되지만 그 뒤로부터는 안된다.

# %% [markdown]
# ##

# %%
import numpy as np #여기서도 교수님 mpg = 내꺼 mpg1으로 생각해주세영

mpg1["grade"] = np.where(mpg1['total'] >= 30, "A",
                np.where(mpg1['total'] >= 20, "B", "C"))

mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
count_grade = mpg1['grade'].value_counts()  # 등급 빈도표 만들기
count_grade
# Out:
# B    118
# C    106
# A     10
# Name: grade, dtype: int64

# %%
import seaborn as sns

# %%
mpg1['grade'].value_counts() #이건 교수님 깃허브에 올려져 있는 걸로 참고, 제대로 못함
# Out:
# B    118
# C    106
# A     10
# Name: grade, dtype: int64

# %%
mpg1['grade'].value_counts().sort_index().index
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
count_grade.plot.bar(rot = 0)
# Out:
# <Axes: >

# %%
sns.countplot(mpg1, x="grade", hue="grade")
# Out:
# <Axes: xlabel='grade', ylabel='count'>

# %%
sns.countplot(mpg1, x="grade", hue="grade", stat='percent');

# %%
# 등급 빈도표 알파벳순 정렬
count_grade = mpg1['grade'].value_counts().sort_index()
count_grade
# Out:
# A     10
# B    118
# C    106
# Name: grade, dtype: int64

# %%
count_grade.index
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
# 등급 빈도 막대 그래프 만들기
count_grade.plot.bar(rot = 0)
# Out:
# <Axes: >

# %%
sns.countplot(mpg1, x="grade", hue="grade", stat='percent', order=["A", "B", "C"]);

# %%
sns.countplot(mpg1, x="grade", hue="grade", order=mpg1['grade'].value_counts().sort_index().index)
# Out:
# <Axes: xlabel='grade', ylabel='count'>

# %%
import numpy as np
np.sort(mpg1['grade'].unique())
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
sns.countplot(mpg1, x="grade", hue="grade", order=np.sort(mpg1['grade'].unique()));

# %% [markdown]
# # 메서드 체이닝 알아두면 좋아요

# %%
s= mpg1['grade']
s= s.value_counts()
s = s.sort_index()
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# A     10
# B    118
# C    106
# Name: grade, dtype: int64

# %%
#메서드 체이닝
s= mpg1['grade'].value_counts().sort_index()

# %% [markdown]
# #필요한 만큼 범주 만들기

# %%
import numpy as np #여기서도 교수님 mpg = 내꺼 mpg1으로 생각해주세영

mpg1["grade"] = np.where(mpg1['total'] >= 35, "A",
                np.where(mpg1['total'] >= 25, "B",
                np.where(mpg1['total'] >= 25, "C","D")))
mpg1.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  test grade
# 0   23.5  pass     D
# 1   25.0  pass     B
# 2   25.5  pass     B
# 3   25.5  pass     B
# 4   21.0  pass     D

# %%
mpg1['size'] = np.where((mpg1['category'] == 'compact') |
                       (mpg1['category'] == 'subcompact') |
                       (mpg1['category'] == '2seater'),
                       'small', 'large')

mpg1['size'].value_counts()
# Out:
# large    147
# small     87
# Name: size, dtype: int64

# %%
mpg1['size'] = np.where(mpg1['category'].isin(['compact', 'subcompact', '2seater']), 'small', 'large') # 시험 문제

mpg1['size'].value_counts()
# Out:
# large    147
# small     87
# Name: size, dtype: int64

# %% [markdown]
# #정리하기

# %%
# 1. 패키지 로드
import pandas as pd
import numpy as np

# 2. 데이터 불러오기
mpg = pd.read_csv('mpg.csv')

# 3. 데이터 파악하기
mpg.shape       # 행, 열 수
mpg.head()      # 데이터 앞부분
mpg.tail()      # 데이터 뒷부분
mpg.info()      # 속성
mpg.describe()  # 요약 통계량

# 4. 변수명 바꾸기
mpg = mpg.rename(columns = {'manufacturer' : 'company'})

# 5. 파생변수 만들기
mpg['total'] = (mpg['cty'] + mpg['hwy'])/2                  # 변수 조합
mpg['test'] = np.where(mpg['total'] >= 20, 'pass', 'fail')  # 조건문 활용

# 6. 빈도 확인하기
count_test = mpg['test'].value_counts()  # 빈도표 만들기
count_test.plot.bar(rot = 0)             # 빈도 막대 그래프 만들기
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB
# <Axes: >

# %%
sns.countplot(mpg, x='test', hue='test');  # 빈도표 만들기

# %%
sns.countplot(mpg, x='test', hue='test', stat='percent');  # 분포비율 만들기
